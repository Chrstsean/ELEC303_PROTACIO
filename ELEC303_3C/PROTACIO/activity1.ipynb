# %% [markdown]
# <h1>ACTIVITY1- PALMER PEMGUINS DATA ANALYTICS PROJECT</h1>

# %% [markdown]
# <h2>Analyst: Christian Owen Protacio</h2>

# %%
 #Libraries

# %%
import numpy as np
import pandas as pd

# %%
penguin = pd.read_csv('datasets\\penguins.csv')

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>DESCRIPTIVE ANALYTICS<h2>

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguin.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %% [markdown]
# <h1>Filtering a column/Data<h1>

# %%
penguin['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguin['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
penguin[penguin['species'] == "Chinstrap"]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
chinstrap_df = penguin[penguin['species'] == "Chinstrap"]

# %%
chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguin['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguin['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
penguin[penguin['species'] == "Gentoo"]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
gentoo_df = penguin[penguin['species'] == "Gentoo"]

# %%
gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
adelie_df = penguin[penguin['species'] == "Adelie"]

# %%
adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
chinstrap_df = penguin[penguin['species'] == "Chinstrap"]

# %%
chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
chinstrap_df['body_mass_g'].mean()
# Out:
# 3733.0882352941176

# %%
gentoo_df['body_mass_g'].mean()
# Out:
# 5076.016260162602

# %%
chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
chinstrap_df['body_mass_g'].mean()
# Out:
# 3733.0882352941176

# %%
chinstrap_df['bill_length_mm'].mean()
# Out:
# 48.83382352941177

# %%
gentoo_df['bill_length_mm'].mean()
# Out:
# 47.50487804878048

# %%
adelie_df['bill_length_mm'].mean()
# Out:
# 38.79139072847682

# %%
penguin['body_mass_g'] >= 4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
penguin['bill_depth_mm'] >= 4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: bill_depth_mm, Length: 344, dtype: bool

# %%
penguin['flipper_length_mm'] >= 4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: flipper_length_mm, Length: 344, dtype: bool

# %% [markdown]
# <h1>CLEANING THE DATA FRAME<h1>

# %%
penguin.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %%
penguin.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1>What to do with all NULL VALUE?<h1>

# %%
penguin['bill_length_mm'].mean()
# Out:
# 43.9219298245614

# %%
penguin['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h1>How To FILLUP NULL VALUES<h1>

# %%
penguin['bill_length_mm'] = penguin['bill_length_mm'].fillna(penguin['flipper_length_mm'].mode())

# %%
penguin.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguin['sex'] = penguin['sex'].fillna(penguin['sex'].mode()[0])
penguin['bill_length_mm'] = penguin['bill_length_mm'].fillna(penguin['bill_length_mm'].mode()[0])
penguin['bill_depth_mm'] = penguin['bill_depth_mm'].fillna(penguin['bill_depth_mm'].mode()[0])
penguin['flipper_length_mm'] = penguin['flipper_length_mm'].fillna(penguin['flipper_length_mm'].mode()[0])
penguin['body_mass_g'] = penguin['body_mass_g'].fillna(penguin['body_mass_g'].mode()[0])

# %%
penguin.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h3>Changing Data Types<h3>

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.905523      17.150291         200.851744  4199.418605
# std          5.447882       1.969061          14.045266   800.197923
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4025.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguin['species'] = penguin['species'].astype('category')
penguin['sex'] = penguin['sex'].astype('category')
penguin['island'] = penguin['island'].astype('category')

# %%
penguin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    int64
# dtypes: category(3), float64(4), int64(1)
# memory usage: 15.0 KB

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.905523      17.150291         200.851744  4199.418605
# std          5.447882       1.969061          14.045266   800.197923
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4025.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# <h2>EXPLORATORY DATA ANALYSIS (EDA) <h2>

# %%
chinstrap_df['body_mass_g'].mean()
# Out:
# 3733.0882352941176

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            41.1           17.0              190.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguin['body_mass_g'].mean()
# Out:
# 4199.418604651163

# %% [markdown]
# <h2>1. What is the average bill length of all penguins?</h2>
# <h4>Insights: The average bill length of penguins is approximately 43.92 mm. This suggests that most penguins in the dataset fall within a moderate bill size range</h4>

# %%
bill_ave = penguin['bill_length_mm'].mean()

# %%
bill_ave
# Out:
# 43.90552325581395

# %% [markdown]
# <h2>2. Who got the most population among all the species?<h2>
# <h4>Insights: Among all penguin species in the dataset, the Adelie penguins have the largest population with 152 individuals, followed by Gentoo (124) and Chinstrap (68). This indicates that Adelie penguins are the most frequently observed species in the dataset, which could reflect their wider distribution, higher abundance in the studied region, or greater sampling representation.</h4>

# %%
penguin['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h2>3. Which species has the highest average body mass and what island and year?<h2>
# <h4>Insights: The Gentoo penguins on Biscoe Island in 2009 recorded the highest average body mass among all species, islands, and years in the dataset. This suggests that Gentoo penguins may generally be larger-bodied compared to Adelie and Chinstrap</h4>

# %%
penguin.groupby(['species','island', 'year'])['body_mass_g'].mean().idxmax()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10864\3636422351.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguin.groupby(['species','island', 'year'])['body_mass_g'].mean().idxmax()
# ('Gentoo', 'Biscoe', 2009)

# %% [markdown]
# <h2>4. What year is the most populated island?<h2>
# <h4>Insights: The year 2009 has the highest penguin population with 120 recorded individuals, followed by 2008 (114) and 2007 (110). This indicates a gradual increase in recorded penguin counts over the three years, with 2009 being the most populated.</h4>

# %%
penguin.groupby(['species','year'])['island'].value_counts()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10864\2725902888.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguin.groupby(['species','year'])['island'].value_counts()
# species    year  island
# Adelie     2007  Dream        20
#                  Torgersen    20
#                  Biscoe       10
#            2008  Biscoe       18
#                  Dream        16
#                  Torgersen    16
#            2009  Dream        20
#                  Biscoe       16
#                  Torgersen    16
# Chinstrap  2007  Dream        26
#                  Biscoe        0
#                  Torgersen     0
#            2008  Dream        18
#                  Biscoe        0
#                  Torgersen     0
#            2009  Dream        24
#                  Biscoe        0
# ...

# %%
penguin['year'].value_counts()
# Out:
# year
# 2009    120
# 2008    114
# 2007    110
# Name: count, dtype: int64

# %% [markdown]
# <h2>5. What is the minimum flipper length recorded, and which year that species belong to?<h2>
# <h4>Insights: The minimum recorded flipper length is 181 mm, and it belongs to an Adelie penguin in the year 2007. This highlights that Adelie penguins in 2007 had the smallest flipper size observed in the dataset.</h4>

# %%
penguin.groupby(['flipper_length_mm','species','year']).describe()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10864\803415300.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguin.groupby(['flipper_length_mm','species','year']).describe()
#                                bill_length_mm                                 \
#                                         count   mean       std   min     25%
# flipper_length_mm species year
# 172.0             Adelie  2007            1.0  37.90       NaN  37.9  37.900
# 174.0             Adelie  2007            1.0  37.80       NaN  37.8  37.800
# 176.0             Adelie  2009            1.0  40.20       NaN  40.2  40.200
# 178.0             Adelie  2007            2.0  38.35  1.626346  37.2  37.775
#                           2008            1.0  33.10       NaN  33.1  33.100
# ...

# %%
min_flipper_idx = penguin['flipper_length_mm'].value_counts()
penguin.loc[min_flipper_idx, ['flipper_length_mm','species','year']]
# Out:
#     flipper_length_mm species  year
# 24              180.0  Adelie  2007
# 17              197.0  Adelie  2007
# 16              195.0  Adelie  2007
# 15              185.0  Adelie  2007
# 14              198.0  Adelie  2007
# 13              191.0  Adelie  2007
# 12              182.0  Adelie  2007
# 10              186.0  Adelie  2007
# 10              186.0  Adelie  2007
# 9               190.0  Adelie  2007
# 8               193.0  Adelie  2007
# 8               193.0  Adelie  2007
# 8               193.0  Adelie  2007
# 8               193.0  Adelie  2007
# 7               195.0  Adelie  2007
# 7               195.0  Adelie  2007
# 7               195.0  Adelie  2007
# 7               195.0  Adelie  2007
# 7               195.0  Adelie  2007
# 7               195.0  Adelie  2007
# 7               195.0  Adelie  2007
# 6               181.0  Adelie  2007
# 6               181.0  Adelie  2007
# 6               181.0  Adelie  2007
# 6               181.0  Adelie  2007
# ...

# %% [markdown]
# <h2>6. Who got the longest flipper length in 2009?<h2>
# <h4>Insights: In 2009, the penguins with the longest average flipper length were the Gentoo penguins on Biscoe Island, measuring about 218.42 mm. This makes them the largest-flippered group compared to Adelie and Chinstrap penguins in the same year.</h4>

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            41.1           17.0              190.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguin['flipper_length_mm'].info() & penguin['species'].describe()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 344 entries, 0 to 343
# Series name: flipper_length_mm
# Non-Null Count  Dtype
# --------------  -----
# 344 non-null    float64
# dtypes: float64(1)
# memory usage: 2.8 KB
# count     False
# unique    False
# top       False
# freq      False
# Name: species, dtype: bool

# %%
penguin.groupby(['species','island', 'year'])['flipper_length_mm'].mean().idxmax()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10864\1225121088.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguin.groupby(['species','island', 'year'])['flipper_length_mm'].mean().idxmax()
# ('Gentoo', 'Biscoe', 2009)

# %% [markdown]
# <h2>DATA AGGREGATION</h2>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
penguin['species'].describe()
# Out:
# count        344
# unique         3
# top       Adelie
# freq         152
# Name: species, dtype: object

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            41.1           17.0              190.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
count_peng = penguin.groupby(['species','island','sex','year']).count()

# %%
count_peng
# Out:
#                                  bill_length_mm  bill_depth_mm  \
# species   island    sex    year
# Adelie    Biscoe    female 2007               5              5
#                            2008               9              9
#                            2009               8              8
#                     male   2007               5              5
#                            2008               9              9
#                            2009               8              8
#           Dream     female 2007               9              9
#                            2008               8              8
#                            2009              10             10
#                     male   2007              11             11
#                            2008               8              8
#                            2009              10             10
#           Torgersen female 2007               8              8
# ...

# %% [markdown]
# <h2>7. What is the average flipper length by species and sex?<h2>
# <h4>Insights: On average, male penguins have longer flippers than females across all species, showing a clear sexual dimorphism.
# Gentoo males have the longest average flipper length (221.18 mm), while Adelie females have the shortest (187.79 mm).</h4>

# %%
penguin.groupby(['species', 'sex'])['flipper_length_mm'].mean()
# Out:
# species    sex
# Adelie     female    187.794521
#            male      191.949367
# Chinstrap  female    191.735294
#            male      199.911765
# Gentoo     female    212.706897
#            male      220.712121
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h2>8. What is the average of the bill length of penguin<h2>
# <h4>Insights: Chinstrap males (≈51 mm) have the longest bills, while Adelie females (≈36 mm) have the shortest. This variation likely reflects differences in diet and ecological adaptations across species.</h4>

# %%
penguin.groupby(['species','island','sex','year'])['bill_length_mm'].mean()
# Out:
# species    island     sex     year
# Adelie     Biscoe     female  2007    37.480000
#                               2008    36.644444
#                               2009    38.087500
#                       male    2007    39.160000
#                               2008    40.755556
#                               2009    41.300000
#            Dream      female  2007    37.855556
#                               2008    36.275000
#                               2009    36.570000
#                       male    2007    40.118182
#                               2008    40.112500
#                               2009    39.730000
#            Torgersen  female  2007    38.275000
#                               2008    36.612500
#                               2009    37.775000
#                       male    2007    39.341667
#                               2008    40.925000
#                               2009    40.850000
# Chinstrap  Biscoe     female  2007          NaN
# ...

# %% [markdown]
# <h2>9. Find the maximum bill depth among Adelie penguins.<h2>
# <h4>Insights: The maximum bill depth recorded among Adelie penguins is 21.5 mm. This indicates that within the Adelie species, some individuals develop relatively deep bills compared to the typical range (around 17–19 mm). A deeper bill may reflect adaptations for feeding on tougher or larger prey.</h4>

# %%
penguin.groupby(['species', 'year'])=='Adelie', penguin['bill_depth_mm'].max()
# Out:
# (False, 21.5)

# %%
penguin[penguin['sex']=='male']['bill_depth_mm'].max()
# Out:
# 21.5

# %% [markdown]
# <h2>10. Who got the minimum bill length among the species<h2>
# <h4>Insights: The shortest bill length recorded among all species belongs to Adelie penguins, with a minimum of 32.1 mm in females on Dream Island (2009). So, the Adelie female (Dream Island, 2009) with 32.1 mm holds the record for the shortest bill in the dataset.</h4>

# %%
low_bill = penguin.groupby(['species','island','sex','year'])['bill_length_mm'].min()

# %%
low_bill
# Out:
# species    island     sex     year
# Adelie     Biscoe     female  2007    35.3
#                               2008    34.5
#                               2009    35.0
#                       male    2007    37.7
#                               2008    37.6
#                               2009    37.8
#            Dream      female  2007    36.0
#                               2008    33.1
#                               2009    32.1
#                       male    2007    37.2
#                               2008    36.3
#                               2009    37.5
#            Torgersen  female  2007    34.4
#                               2008    33.5
#                               2009    35.2
#                       male    2007    34.1
#                               2008    35.1
#                               2009    37.3
# Chinstrap  Biscoe     female  2007     NaN
#                               2008     NaN
#                               2009     NaN
# ...

# %% [markdown]
# <h2>11. Who got the maximum bill legnth among the species <h2>
# <h4>Insights: The longest bill length among all species belongs to Gentoo males on Biscoe Island in 2007, measuring 59.6 mm.
# Overall, the Gentoo male (Biscoe Island, 2007, 59.6 mm) holds the record for the longest bill in the dataset, reinforcing that Gentoo penguins are typically the largest species in terms of body size and feeding adaptations.</h4>

# %%
max_bill = penguin.groupby(['species','island','sex','year'])['bill_length_mm'].max()

# %%
max_bill
# Out:
# species    island     sex     year
# Adelie     Biscoe     female  2007    40.5
#                               2008    39.6
#                               2009    39.7
#                       male    2007    40.6
#                               2008    42.0
#                               2009    45.6
#            Dream      female  2007    42.2
#                               2008    38.9
#                               2009    40.2
#                       male    2007    44.1
#                               2008    43.2
#                               2009    41.5
#            Torgersen  female  2007    41.1
#                               2008    40.9
#                               2009    40.2
#                       male    2007    46.0
#                               2008    45.8
#                               2009    44.1
# Chinstrap  Biscoe     female  2007     NaN
#                               2008     NaN
#                               2009     NaN
# ...

# %% [markdown]
# <h2>Correlation Analysis<h2>
# <hr>
# <h3>is there a correlation between bodymass and bill length <h3>

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            41.1           17.0              190.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
corr_year_mass = penguin['body_mass_g'].corr(penguin['bill_length_mm'])

# %%
corr_year_mass
# Out:
# 0.5957197979602955

# %% [markdown]
# <h2>12. Is there a correlation between the bodymass and bill depth?<h2>
# <h4>Insights: The correlation between body mass and bill depth is -0.47, which indicates a moderate negative relationship. This means that as penguins’ body mass increases, their bill depth tends to decrease, and vice versa.</h4>

# %%
penguin['body_mass_g'].corr(penguin['bill_depth_mm'])
# Out:
# -0.47133919548221503

# %% [markdown]
# <h1>Categorical to Numerical Correlation<h1>
# <h2>Using One Way Anova<h2>
# <h2>Librarry Scientific Python (Scipy)<h2>

# %%
from scipy.stats import f_oneway

# %%
male_df = penguin[penguin['sex'] == 'male']

# %%
male_df['body_mass_g']
# Out:
# 0      3750.0
# 3      3800.0
# 5      3650.0
# 7      4675.0
# 8      3475.0
#         ...
# 334    3800.0
# 336    3950.0
# 339    4000.0
# 341    3775.0
# 342    4100.0
# Name: body_mass_g, Length: 179, dtype: float64

# %%
penguin[penguin['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.0
# 3      3800.0
# 5      3650.0
# 7      4675.0
# 8      3475.0
#         ...
# 334    3800.0
# 336    3950.0
# 339    4000.0
# 341    3775.0
# 342    4100.0
# Name: body_mass_g, Length: 179, dtype: float64

# %%
f_oneway(penguin[penguin['species'] == 'Gentoo']['body_mass_g'], penguin[penguin['species'] == 'Chinstrap']['body_mass_g'],
         penguin[penguin['species'] == 'Adelie']['body_mass_g'])
# Out:
# F_onewayResult(statistic=335.06911860906183, pvalue=3.2690801884058894e-81)

# %%
penguin['sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339     True
# 340    False
# 341     True
# 342     True
# 343    False
# Name: sex, Length: 344, dtype: bool

# %%
penguin[penguin['sex'] == 'male']['body_mass_g'], penguin[penguin['sex'] == 'female']['body_mass_g'].mean()
# Out:
# (0      3750.0
#  3      3800.0
#  5      3650.0
#  7      4675.0
#  8      3475.0
#          ...
#  334    3800.0
#  336    3950.0
#  339    4000.0
#  341    3775.0
#  342    4100.0
#  Name: body_mass_g, Length: 179, dtype: float64,
#  3862.2727272727275)

# %%
penguin[penguin['species'] == 'Gentoo']['body_mass_g'], penguin[penguin['species'] == 'Adelie']['body_mass_g'], penguin[penguin['species'] == 'Chinstrap']['body_mass_g'].mean()
# Out:
# (152    4500.0
#  153    5700.0
#  154    4450.0
#  155    5700.0
#  156    5400.0
#          ...
#  271    3800.0
#  272    4850.0
#  273    5750.0
#  274    5200.0
#  275    5400.0
#  Name: body_mass_g, Length: 124, dtype: float64,
#  0      3750.0
#  1      3800.0
#  2      3250.0
#  3      3800.0
#  4      3450.0
#          ...
#  147    3475.0
#  148    3450.0
#  149    3750.0
#  150    3700.0
#  151    4000.0
#  Name: body_mass_g, Length: 152, dtype: float64,
#  3733.0882352941176)

# %% [markdown]
# <h2>13. Find the maximum body mass of Gentoo penguins vs. Chinstrap penguins.<h2>
# <h4>Insights: This shows that Gentoo penguins are significantly heavier than Chinstrap penguins, with their heaviest individuals weighing about 1.5 kg more. The size difference highlights Gentoo penguins as the largest-bodied species in the dataset, consistent with their reputation for being strong swimmers and deep divers.</h4>

# %%
penguin[penguin['species'] == 'Gentoo']['body_mass_g'].max(), \
penguin[penguin['species'] == 'Chinstrap']['body_mass_g'].max()
# Out:
# (6300.0, 4800.0)

# %% [markdown]
# <h2>14. Lets use the sum of body mass per year.<h2>
# <h4>Insights: Gentoo penguins dominate the total body mass contribution each year, followed by Adelie, while Chinstrap contributes the least. This reinforces the idea that Gentoo penguins are both heavier individually and well-represented in population weight totals.</h4>

# %%
penguin.groupby(['species','year'])['body_mass_g'].sum()
# Out:
# species    year
# Adelie     2007    184925.0
#            2008    187100.0
#            2009    190575.0
# Chinstrap  2007     96050.0
#            2008     68400.0
#            2009     89400.0
# Gentoo     2007    172400.0
#            2008    230900.0
#            2009    224850.0
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h2>15. What is the median flipper length per island?<h2>
# <h4>Insights: Gentoo penguins on Biscoe Island have the largest median flipper length (216 mm), while Adelie penguins across the islands have the smallest (~190 mm). This suggests that island habitat and species type strongly influence penguin body size traits.</h4>

# %%
penguin.groupby(['species','island'])['flipper_length_mm'].median()
# Out:
# species    island
# Adelie     Biscoe       189.5
#            Dream        190.0
#            Torgersen    190.5
# Chinstrap  Biscoe         NaN
#            Dream        196.0
#            Torgersen      NaN
# Gentoo     Biscoe       216.0
#            Dream          NaN
#            Torgersen      NaN
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h2>16. Let's see the size of every sex of the species<h2>
# <h4>Insights: In the dataset, there are slightly more male penguins (179) than female penguins (165). The dataset reflects a healthy near-equal male-to-female ratio, ensuring that comparisons between sexes remain meaningful.</h4>

# %%
penguin.groupby('sex').size()
# Out:
# sex
# female    165
# male      179
# dtype: int64

# %% [markdown]
# <h2>DATA VISUALIZATION</h2>

# %%
import matplotlib.pyplot as plt

# %%
penguin_count = penguin['species'].value_counts()

# %%
penguin_count.values
# Out:
# array([152, 124,  68], dtype=int64)

# %%
#plt.bar(x, y, optional_values .....)
plt.bar(penguin_count.index, penguin_count.values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(penguin_count.index, penguin_count.values, color = ['Red', 'Yellow', 'Green'])
plt.xlabel('penguin')
plt.ylabel('population')
plt.show()

# %%
plt.bar(penguin_count.index, penguin_count.values, color = ['Red', 'Yellow', 'Green'])
plt.xlabel('species')
plt.ylabel('body_mass_g')
plt.show()
